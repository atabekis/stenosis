# %%
import os
from collections import defaultdict

from config import DANILOV_DATASET_DIR, DANILOV_DATASET_PATH
from reader import Reader

# %% [markdown]
# First, I check whether there are non-matching files in the `dataset/` directory

# %%
dataset = DANILOV_DATASET_DIR / "dataset"
bmp_files, xml_files = [f for f in os.listdir(dataset) if f.endswith(".bmp")], [f for f in os.listdir(dataset) if f.endswith(".xml")]
bmp_basenames, xml_basenames = {os.path.splitext(f)[0] for f in bmp_files}, {os.path.splitext(f)[0] for f in xml_files}

only_bmp = bmp_basenames - xml_basenames
only_xml = xml_basenames - bmp_basenames
both = bmp_basenames & xml_basenames

print("BMP only  :", len(only_bmp))
print("XML only  :", len(only_xml))
print("Matched   :", len(both))
# Out:
# BMP only  : 0
# XML only  : 0
# Matched   : 8325

# %% [markdown]
# Great, we have all matching image and ground truth files. Now I will check the two `.csv` files provided with the data.

# %%
import pandas as pd

train_df, test_df = pd.read_csv(DANILOV_DATASET_DIR / "train_labels.csv"), pd.read_csv(DANILOV_DATASET_DIR / "test_labels.csv")

print(train_df.columns)
train_df.head()
# Out:
# Index(['filename', 'width', 'height', 'class', 'xmin', 'ymin', 'xmax', 'ymax'], dtype='object')
#             filename  width  height     class  xmin  ymin  xmax  ymax
# 0  14_024_2_0042.bmp    800     800  Stenosis   235   156   282   192
# 1  14_031_4_0031.bmp    800     800  Stenosis   419   319   446   349
# 2  14_046_5_0066.bmp   1000    1000  Stenosis   679   307   699   336
# 3  14_010_6_0035.bmp    512     512  Stenosis    94   244   126   286
# 4  14_014_1_0015.bmp    512     512  Stenosis   163   118   203   151

# %%
bboxes_per_image = train_df.groupby("filename").size().reset_index(name='count')
print(bboxes_per_image['count'].unique())
print(bboxes_per_image['count'].value_counts())
bboxes_per_image
# Out:
# [1 2]
# count
# 1    7491
# 2       1
# Name: count, dtype: int64
#                filename  count
# 0     14_002_5_0016.bmp      1
# 1     14_002_5_0017.bmp      2
# 2     14_002_5_0020.bmp      1
# 3     14_002_5_0021.bmp      1
# 4     14_002_5_0022.bmp      1
# ...                 ...    ...
# 7487  14_099_8_0007.bmp      1
# 7488  14_099_8_0008.bmp      1
# 7489  14_099_8_0009.bmp      1
# 7490  14_099_8_0011.bmp      1
# 7491  14_099_8_0012.bmp      1
#
# [7492 rows x 2 columns]

# %% [markdown]
# This shows that there is a case (first patient, first video, second frame) includes two bounding boxes for stenosis. This is strange since visual inspection of the pictures show that the before and after frames of `14_002_0017.bmp` show only one bounding box. The following includes the description of bounding box stats:

# %%
bboxes_per_image.describe()
# Out:
#              count
# count  7492.000000
# mean      1.000133
# std       0.011553
# min       1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       1.000000
# max       2.000000

# %% [markdown]
# The following code is used to see whether there are multiple views of the stenosis for the same patient. The filenames in the `dataset/` directory are structured as follows:
# `14_PatientId_VideoId_FrameNr`

# %%
import re
pattern = re.compile(r"^14_(\d+)_(\d+)_(\d+)$")
rows = []

for base_name in both:
    m = pattern.match(base_name)
    if m:
        patient_id, video_id, frame_nr = int(m.group(1)), int(m.group(2)), int(m.group(3))
        rows.append((patient_id, video_id, frame_nr))

df_pv = pd.DataFrame(rows, columns=['patient_id', 'video_id', 'frame_nr'])

df_pv.sort_values(by=["patient_id","video_id","frame_nr"], inplace=True)

df_grouped_patient = df_pv.groupby("patient_id")

for pid, group in df_grouped_patient:
    n_videos     = group["video_id"].nunique()
    total_frames = len(group)
    print(f"Patient {pid} has {n_videos} video(s), with {total_frames} total frames.")
    
    # Within each patient group, break down frames by each video
    video_groups = group.groupby("video_id")
    for vid, vgroup in video_groups:
        frames_count = len(vgroup)
        print(f"  - Video {vid}: {frames_count} frame(s)")

    print("----------------------------------------------------")
# Out:
# Patient 2 has 2 video(s), with 53 total frames.
#   - Video 5: 33 frame(s)
#   - Video 8: 20 frame(s)
# ----------------------------------------------------
# Patient 3 has 2 video(s), with 44 total frames.
#   - Video 1: 27 frame(s)
#   - Video 2: 17 frame(s)
# ----------------------------------------------------
# Patient 6 has 1 video(s), with 113 total frames.
#   - Video 1: 113 frame(s)
# ----------------------------------------------------
# Patient 7 has 5 video(s), with 374 total frames.
#   - Video 3: 67 frame(s)
#   - Video 5: 88 frame(s)
#   - Video 6: 67 frame(s)
#   - Video 8: 89 frame(s)
#   - Video 10: 63 frame(s)
# ----------------------------------------------------
# Patient 10 has 2 video(s), with 82 total frames.
#   - Video 1: 50 frame(s)
#   - Video 6: 32 frame(s)
# ----------------------------------------------------
# Patient 12 has 2 video(s), with 36 total frames.
#   - Video 3: 13 frame(s)
#   - Video 4: 23 frame(s)
# ----------------------------------------------------
# Patient 14 has 1 video(s), with 23 total frames.
#   - Video 1: 23 frame(s)
# ----------------------------------------------------
# Patient 15 has 1 video(s), with 67 total frames.
#   - Video 1: 67 frame(s)
# ----------------------------------------------------
# Patient 16 has 1 video(s), with 70 total frames.
#   - Video 1: 70 frame(s)
# ----------------------------------------------------
# Patient 17 has 1 video(s), with 36 total frames.
#   - Video 1: 36 frame(s)
# ----------------------------------------------------
# Patient 18 has 2 video(s), with 72 total frames.
#   - Video 6: 42 frame(s)
#   - Video 8: 30 frame(s)
# ----------------------------------------------------
# Patient 19 has 1 video(s), with 73 total frames.
#   - Video 5: 73 frame(s)
# ----------------------------------------------------
# Patient 21 has 15 video(s), with 543 total frames.
#   - Video 1: 75 frame(s)
#   - Video 2: 14 frame(s)
#   - Video 4: 45 frame(s)
#   - Video 5: 29 frame(s)
#   - Video 6: 46 frame(s)
#   - Video 15: 42 frame(s)
#   - Video 16: 67 frame(s)
#   - Video 29: 25 frame(s)
#   - Video 30: 30 frame(s)
#   - Video 31: 27 frame(s)
#   - Video 32: 18 frame(s)
#   - Video 34: 26 frame(s)
#   - Video 35: 28 frame(s)
#   - Video 37: 39 frame(s)
#   - Video 38: 32 frame(s)
# ----------------------------------------------------
# Patient 22 has 5 video(s), with 235 total frames.
#   - Video 1: 46 frame(s)
#   - Video 2: 40 frame(s)
#   - Video 3: 41 frame(s)
#   - Video 6: 55 frame(s)
#   - Video 7: 53 frame(s)
# ----------------------------------------------------
# Patient 23 has 3 video(s), with 124 total frames.
#   - Video 2: 56 frame(s)
#   - Video 3: 30 frame(s)
#   - Video 4: 38 frame(s)
# ----------------------------------------------------
# Patient 24 has 6 video(s), with 272 total frames.
#   - Video 1: 43 frame(s)
#   - Video 2: 40 frame(s)
#   - Video 3: 52 frame(s)
#   - Video 4: 42 frame(s)
#   - Video 5: 45 frame(s)
#   - Video 6: 50 frame(s)
# ----------------------------------------------------
# Patient 26 has 2 video(s), with 162 total frames.
#   - Video 2: 121 frame(s)
#   - Video 3: 41 frame(s)
# ----------------------------------------------------
# Patient 28 has 3 video(s), with 148 total frames.
#   - Video 1: 59 frame(s)
#   - Video 2: 51 frame(s)
#   - Video 3: 38 frame(s)
# ----------------------------------------------------
# Patient 29 has 6 video(s), with 326 total frames.
#   - Video 1: 41 frame(s)
#   - Video 2: 51 frame(s)
#   - Video 4: 51 frame(s)
#   - Video 5: 71 frame(s)
#   - Video 6: 71 frame(s)
#   - Video 7: 41 frame(s)
# ----------------------------------------------------
# Patient 31 has 6 video(s), with 271 total frames.
#   - Video 3: 36 frame(s)
#   - Video 4: 41 frame(s)
#   - Video 5: 41 frame(s)
#   - Video 6: 46 frame(s)
#   - Video 7: 61 frame(s)
#   - Video 8: 46 frame(s)
# ----------------------------------------------------
# Patient 32 has 3 video(s), with 133 total frames.
#   - Video 4: 46 frame(s)
#   - Video 6: 46 frame(s)
#   - Video 7: 41 frame(s)
# ----------------------------------------------------
# Patient 33 has 2 video(s), with 142 total frames.
#   - Video 3: 66 frame(s)
#   - Video 4: 76 frame(s)
# ----------------------------------------------------
# Patient 34 has 2 video(s), with 67 total frames.
#   - Video 6: 36 frame(s)
#   - Video 7: 31 frame(s)
# ----------------------------------------------------
# Patient 39 has 5 video(s), with 235 total frames.
#   - Video 1: 41 frame(s)
#   - Video 2: 36 frame(s)
#   - Video 4: 61 frame(s)
#   - Video 5: 66 frame(s)
#   - Video 7: 31 frame(s)
# ----------------------------------------------------
# Patient 40 has 5 video(s), with 126 total frames.
#   - Video 1: 31 frame(s)
#   - Video 2: 25 frame(s)
#   - Video 3: 23 frame(s)
#   - Video 5: 26 frame(s)
#   - Video 7: 21 frame(s)
# ----------------------------------------------------
# Patient 42 has 5 video(s), with 230 total frames.
#   - Video 1: 43 frame(s)
#   - Video 2: 41 frame(s)
#   - Video 3: 60 frame(s)
#   - Video 4: 46 frame(s)
#   - Video 5: 40 frame(s)
# ----------------------------------------------------
# Patient 44 has 4 video(s), with 111 total frames.
#   - Video 1: 36 frame(s)
#   - Video 2: 20 frame(s)
#   - Video 3: 21 frame(s)
#   - Video 5: 34 frame(s)
# ----------------------------------------------------
# Patient 46 has 3 video(s), with 148 total frames.
#   - Video 3: 42 frame(s)
#   - Video 5: 60 frame(s)
#   - Video 6: 46 frame(s)
# ----------------------------------------------------
# Patient 48 has 5 video(s), with 332 total frames.
#   - Video 1: 68 frame(s)
#   - Video 2: 81 frame(s)
#   - Video 3: 61 frame(s)
#   - Video 4: 56 frame(s)
#   - Video 5: 66 frame(s)
# ----------------------------------------------------
# Patient 49 has 3 video(s), with 86 total frames.
#   - Video 1: 26 frame(s)
#   - Video 3: 24 frame(s)
#   - Video 4: 36 frame(s)
# ----------------------------------------------------
# Patient 50 has 5 video(s), with 136 total frames.
#   - Video 4: 16 frame(s)
#   - Video 6: 22 frame(s)
#   - Video 8: 36 frame(s)
#   - Video 9: 36 frame(s)
#   - Video 10: 26 frame(s)
# ----------------------------------------------------
# Patient 51 has 5 video(s), with 122 total frames.
#   - Video 2: 41 frame(s)
#   - Video 5: 21 frame(s)
#   - Video 6: 16 frame(s)
#   - Video 8: 21 frame(s)
#   - Video 10: 23 frame(s)
# ----------------------------------------------------
# Patient 52 has 1 video(s), with 14 total frames.
#   - Video 1: 14 frame(s)
# ----------------------------------------------------
# Patient 53 has 4 video(s), with 209 total frames.
#   - Video 1: 46 frame(s)
#   - Video 2: 56 frame(s)
#   - Video 4: 56 frame(s)
#   - Video 5: 51 frame(s)
# ----------------------------------------------------
# Patient 55 has 3 video(s), with 55 total frames.
#   - Video 5: 28 frame(s)
#   - Video 6: 9 frame(s)
#   - Video 8: 18 frame(s)
# ----------------------------------------------------
# Patient 57 has 2 video(s), with 87 total frames.
#   - Video 2: 46 frame(s)
#   - Video 3: 41 frame(s)
# ----------------------------------------------------
# Patient 58 has 2 video(s), with 49 total frames.
#   - Video 3: 26 frame(s)
#   - Video 4: 23 frame(s)
# ----------------------------------------------------
# Patient 59 has 2 video(s), with 87 total frames.
#   - Video 1: 51 frame(s)
#   - Video 2: 36 frame(s)
# ----------------------------------------------------
# Patient 62 has 3 video(s), with 128 total frames.
#   - Video 2: 51 frame(s)
#   - Video 3: 41 frame(s)
#   - Video 5: 36 frame(s)
# ----------------------------------------------------
# Patient 64 has 2 video(s), with 62 total frames.
#   - Video 2: 31 frame(s)
#   - Video 3: 31 frame(s)
# ----------------------------------------------------
# Patient 66 has 6 video(s), with 196 total frames.
#   - Video 2: 36 frame(s)
#   - Video 3: 16 frame(s)
#   - Video 7: 36 frame(s)
#   - Video 8: 51 frame(s)
#   - Video 9: 16 frame(s)
#   - Video 10: 41 frame(s)
# ----------------------------------------------------
# Patient 67 has 2 video(s), with 31 total frames.
#   - Video 4: 17 frame(s)
#   - Video 7: 14 frame(s)
# ----------------------------------------------------
# Patient 68 has 4 video(s), with 76 total frames.
#   - Video 1: 11 frame(s)
#   - Video 2: 18 frame(s)
#   - Video 3: 31 frame(s)
#   - Video 6: 16 frame(s)
# ----------------------------------------------------
# Patient 69 has 1 video(s), with 46 total frames.
#   - Video 1: 46 frame(s)
# ----------------------------------------------------
# Patient 70 has 3 video(s), with 92 total frames.
#   - Video 3: 25 frame(s)
#   - Video 4: 36 frame(s)
#   - Video 5: 31 frame(s)
# ----------------------------------------------------
# Patient 73 has 1 video(s), with 27 total frames.
#   - Video 1: 27 frame(s)
# ----------------------------------------------------
# Patient 75 has 7 video(s), with 148 total frames.
#   - Video 1: 16 frame(s)
#   - Video 2: 19 frame(s)
#   - Video 3: 19 frame(s)
#   - Video 4: 31 frame(s)
#   - Video 5: 26 frame(s)
#   - Video 6: 21 frame(s)
#   - Video 8: 16 frame(s)
# ----------------------------------------------------
# Patient 76 has 2 video(s), with 23 total frames.
#   - Video 3: 12 frame(s)
#   - Video 4: 11 frame(s)
# ----------------------------------------------------
# Patient 77 has 2 video(s), with 112 total frames.
#   - Video 5: 51 frame(s)
#   - Video 6: 61 frame(s)
# ----------------------------------------------------
# Patient 80 has 2 video(s), with 87 total frames.
#   - Video 2: 66 frame(s)
#   - Video 3: 21 frame(s)
# ----------------------------------------------------
# Patient 81 has 5 video(s), with 119 total frames.
#   - Video 3: 29 frame(s)
#   - Video 6: 17 frame(s)
#   - Video 7: 31 frame(s)
#   - Video 10: 21 frame(s)
#   - Video 11: 21 frame(s)
# ----------------------------------------------------
# Patient 83 has 3 video(s), with 84 total frames.
#   - Video 1: 29 frame(s)
#   - Video 6: 34 frame(s)
#   - Video 7: 21 frame(s)
# ----------------------------------------------------
# Patient 84 has 7 video(s), with 234 total frames.
#   - Video 1: 41 frame(s)
#   - Video 3: 36 frame(s)
#   - Video 4: 16 frame(s)
#   - Video 5: 38 frame(s)
#   - Video 6: 31 frame(s)
#   - Video 7: 41 frame(s)
#   - Video 9: 31 frame(s)
# ----------------------------------------------------
# Patient 85 has 4 video(s), with 204 total frames.
#   - Video 1: 51 frame(s)
#   - Video 2: 41 frame(s)
#   - Video 4: 61 frame(s)
#   - Video 5: 51 frame(s)
# ----------------------------------------------------
# Patient 87 has 3 video(s), with 188 total frames.
#   - Video 1: 56 frame(s)
#   - Video 2: 71 frame(s)
#   - Video 3: 61 frame(s)
# ----------------------------------------------------
# Patient 88 has 6 video(s), with 200 total frames.
#   - Video 1: 41 frame(s)
#   - Video 2: 26 frame(s)
#   - Video 3: 31 frame(s)
#   - Video 5: 25 frame(s)
#   - Video 6: 26 frame(s)
#   - Video 8: 51 frame(s)
# ----------------------------------------------------
# Patient 91 has 1 video(s), with 11 total frames.
#   - Video 1: 11 frame(s)
# ----------------------------------------------------
# Patient 92 has 2 video(s), with 67 total frames.
#   - Video 1: 41 frame(s)
#   - Video 2: 26 frame(s)
# ----------------------------------------------------
# Patient 94 has 2 video(s), with 67 total frames.
#   - Video 2: 36 frame(s)
#   - Video 3: 31 frame(s)
# ----------------------------------------------------
# Patient 95 has 6 video(s), with 281 total frames.
#   - Video 1: 51 frame(s)
#   - Video 2: 51 frame(s)
#   - Video 4: 56 frame(s)
#   - Video 5: 36 frame(s)
#   - Video 7: 46 frame(s)
#   - Video 8: 41 frame(s)
# ----------------------------------------------------
# Patient 96 has 5 video(s), with 235 total frames.
#   - Video 2: 51 frame(s)
#   - Video 3: 46 frame(s)
#   - Video 4: 41 frame(s)
#   - Video 5: 46 frame(s)
#   - Video 6: 51 frame(s)
# ----------------------------------------------------
# Patient 97 has 2 video(s), with 40 total frames.
#   - Video 1: 16 frame(s)
#   - Video 2: 24 frame(s)
# ----------------------------------------------------
# Patient 98 has 2 video(s), with 38 total frames.
#   - Video 3: 22 frame(s)
#   - Video 4: 16 frame(s)
# ----------------------------------------------------
# Patient 99 has 3 video(s), with 36 total frames.
#   - Video 5: 15 frame(s)
#   - Video 6: 14 frame(s)
#   - Video 8: 7 frame(s)
# ----------------------------------------------------

# %% [markdown]
# Further, I will follow with some visualizations in order to see whether these are really different videos from different angles or the same, i.e., multi-view vs. single-view

# %%
from reader import Reader
r = Reader(dataset_dir=DANILOV_DATASET_DIR)
# Out:
# [23:08:34][reader.Reader._merge_labels] "Merged dataset found at C:\Users\Ata\Desktop\BEP\Code\data\DANILOV\labels.csv. Loading merged dataset"
# [23:08:34][reader.Reader._load_danilov] "Building XCA images from CSV files using the Danilov dataset."

# %%
from visualize import show_xca_image

def find_patient_with_most_views(reader):
    from collections import defaultdict
    
    patient_videos = defaultdict(set)
    
    for img in reader.xca_images:
        patient_videos[img.patient_id].add(img.video_id)
    
    max_videos, max_video_patient = 0, None
    
    for pid, vids in patient_videos.items():
        if len(vids) > max_videos:
            max_videos, best_patient = len(vids), pid
    
    return best_patient, max_videos

pid, vid_count = find_patient_with_most_views(r)
print(f"Patient {pid} has the most videos: {vid_count}")
# Out:
# Patient 21 has the most videos: 15

# %%
test_patient = 2
patient_videos = r.get(patient_id=test_patient, return_videos=True)

def group_videos(vids):
    grouped_videos = dict()
    for vid in vids:
        if vid.video_id not in grouped_videos:
            grouped_videos[vid.video_id] = [vid]
        else:
            grouped_videos[vid.video_id].append(vid)
    
    grouped_videos = sorted(grouped_videos.keys())
    return grouped_videos
grouped_videos = group_videos(patient_videos)
grouped_videos
# Out:
# [5, 8]

# %%
img = r.get(patient_id=1, video_id=1)  # random frame
show_xca_image(img)
